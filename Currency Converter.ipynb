# %%
from tkinter import * 
root = Tk()
root.geometry("700x500")
root.config(bg = "yellow")
Font_tuple = ("Comic Sans MS", 20, "bold")

def from_rs():
    USD = float(e1_value.get())*0.012
    
    t1.delete("1.0", END)
    t1.insert(END, USD)

m0 = Label(root,text = "Welcome to Currency Convertor", width =50,height=2, bg = "green", fg = "red", font = Font_tuple).place(x=350,y=20)
m1 = Label(root, text = "Rupees to USD",bg = "green", fg = "red", font = Font_tuple).place(x=50,y=120)
m2 = Label(root,text = "Rupees to pounds",bg = "green", fg = "red", font = Font_tuple).place(x=50,y=180)
m3 = Label(root, text = "USD to rupees",bg = "green", fg = "red", font = Font_tuple).place(x=50,y=240)
m4 = Label(root, text = "Pounds to rupees",bg = "green", fg = "red", font = Font_tuple).place(x=50,y=300)
m5 = Label(root, text = "USD to pounds",bg = "green", fg = "red", font = Font_tuple).place(x=50,y=360)
m6 = Label(root, text = "Pounds to USD",bg = "green", fg = "red", font = Font_tuple).place(x=50,y=420)

e1_value = StringVar()
e2_value = StringVar()
e3_value = StringVar()
e4_value = StringVar()
e5_value = StringVar()
e6_value = StringVar()

e1 = Entry(root, width= 20, font=Font_tuple, bg="cyan", textvariable = e1_value).place(x=300,y=120)
e2 = Entry(root, width= 20, font=Font_tuple, bg="cyan",  textvariable = e2_value).place(x=300,y=180)
e3 = Entry(root, width= 20, font=Font_tuple, bg="cyan",  textvariable = e3_value).place(x=300,y=240)
e4 = Entry(root, width= 20, font=Font_tuple, bg="cyan",  textvariable = e4_value).place(x=300,y=300)
e5 = Entry(root, width= 20, font=Font_tuple, bg="cyan",  textvariable = e5_value).place(x=300,y=360)
e6 = Entry(root, width= 20, font=Font_tuple, bg="cyan",  textvariable = e6_value).place(x=300,y=420)

Font_tuple2 = ("Comic Sans MS", 12, "bold")

t1 = Text(root, width= 20, height=1, font = Font_tuple).place(x=800,y=120)
t2 = Text(root, width= 20, height=1, font = Font_tuple).place(x=800,y=180)
t3 = Text(root, width= 20, height=1, font = Font_tuple).place(x=800,y=240)
t4 = Text(root, width= 20, height=1, font = Font_tuple).place(x=800,y=300)
t5 = Text(root, width= 20, height=1, font = Font_tuple).place(x=800,y=360)
t6 = Text(root, width= 20, height=1, font = Font_tuple).place(x=800,y=420)

b1 = Button(root, text = "CONVERT", font=Font_tuple2, bg = "blue", fg="white", command = from_rs).place(x=650,y=120)
b2 = Button(root, text = "CONVERT", font=Font_tuple2, bg = "blue", fg="white").place(x=650,y=180)
b3 = Button(root, text = "CONVERT", font=Font_tuple2, bg = "blue", fg="white").place(x=650,y=240)
b4 = Button(root, text = "CONVERT", font=Font_tuple2, bg = "blue", fg="white").place(x=650,y=300)
b5 = Button(root, text = "CONVERT", font=Font_tuple2, bg = "blue", fg="white").place(x=650,y=360)
b6 = Button(root, text = "CONVERT", font=Font_tuple2, bg = "blue", fg="white").place(x=650,y=420)







root.mainloop()
